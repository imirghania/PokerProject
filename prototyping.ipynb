# %%
import json
import numpy as np
import pandas as pd
import re
from copy import copy

# %%
with open('hands.json', 'r') as file:
    data = json.load(file)

# %%
len(data)
# Out:
# 439682

# %%
first_obj = data[0]

# %%
first_obj
# Out:
# {'_id': 'holdem3_199505_800160769',
#  'board': [],
#  'dealer': 1,
#  'game': 'holdem3',
#  'hand_num': 1,
#  'num_players': 2,
#  'players': {'A8': {'total_bet': 25,
#    'bankroll': 8371,
#    'bets': [{'actions': 'Bf', 'stage': 'p'},
#     {'actions': '-', 'stage': 'f'},
#     {'actions': '-', 'stage': 't'},
#     {'actions': '-', 'stage': 'r'}],
#    'pocket_cards': [],
#    'position': 1,
#    'total_win': 0},
#   'Schween': {'total_bet': 50,
#    'bankroll': 8035,
#    'bets': [{'actions': 'B', 'stage': 'p'},
#     {'actions': '-', 'stage': 'f'},
#     {'actions': '-', 'stage': 't'},
#     {'actions': '-', 'stage': 'r'}],
#    'pocket_cards': [],
#    'position': 2,
#    'total_win': 75}},
#  'pots': [{'num_players': 0, 'stage': 'f', 'size': 0},
#   {'num_players': 0, 'stage': 't', 'size': 0},
#   {'num_players': 0, 'stage': 'r', 'size': 0},
#   {'num_players': 1, 'stage': 's', 'size': 75}]}

# %%
first_obj['_id']
# Out:
# 'holdem3_199505_800160769'

# %%
first_obj['_id'].split('_')
# Out:
# ['holdem3', '199505', '800160769']

# %%
_, year_month, timestamp = first_obj['_id'].split('_')

# %%
year_month, timestamp
# Out:
# ('199505', '800160769')

# %%
year_month[:4], year_month[4:]
# Out:
# ('1995', '05')

# %%
def extract_date(obj: dict, id_str: str):
    _, year_month, timestamp = obj[id_str].split('_')
    return year_month[:4], year_month[4:], timestamp

# %%
second_obj = data[1]

# %%
second_obj
# Out:
# {'_id': 'holdem3_199505_800160788',
#  'board': ['Jc', 'Qs', '6s', '6d'],
#  'dealer': 1,
#  'game': 'holdem3',
#  'hand_num': 2,
#  'num_players': 2,
#  'players': {'A8': {'total_bet': 250,
#    'bankroll': 8346,
#    'bets': [{'actions': 'Br', 'stage': 'p'},
#     {'actions': 'b', 'stage': 'f'},
#     {'actions': 'bf', 'stage': 't'},
#     {'actions': '-', 'stage': 'r'}],
#    'pocket_cards': [],
#    'position': 2,
#    'total_win': 0},
#   'Schween': {'total_bet': 350,
#    'bankroll': 8060,
#    'bets': [{'actions': 'Bcc', 'stage': 'p'},
#     {'actions': 'kc', 'stage': 'f'},
#     {'actions': 'kr', 'stage': 't'},
#     {'actions': '-', 'stage': 'r'}],
#    'pocket_cards': [],
#    'position': 1,
#    'total_win': 600}},
#  'pots': [{'num_players': 2, 'stage': 'f', 'size': 200},
#   {'num_players': 2, 'stage': 't', 'size': 300},
#   {'num_players': 0, 'stage': 'r', 'size': 0},
#   {'num_players': 1, 'stage': 's', 'size': 600}]}

# %%
board_cards = second_obj['board']
pocket_cards = {player_name: player_data["pocket_cards"] for player_name, player_data in second_obj['players'].items()}

# %%
board_cards, pocket_cards
# Out:
# (['Jc', 'Qs', '6s', '6d'], {'A8': [], 'Schween': []})

# %%
def normalize_cards_list(board: list, cards_num=5, padding_element='-'):
    normalize_board = copy(board)
    cards_number = len(board)
    if cards_number == cards_num:
        return normalize_board
    else:
        appendex_number = cards_num - cards_number
        appendex = [padding_element] * appendex_number
        normalize_board.extend(appendex)
    return normalize_board

# %%
normalize_cards_list(board_cards, padding_element=None)
# Out:
# ['Jc', 'Qs', '6s', '6d', None]

# %%
normalize_cards_list([], cards_num=2, padding_element=None)
# Out:
# [None, None]

# %%
players = first_obj['players']

# %%
for player in list(players.values()):
    player_label = f"player{player['position']}"
    print(player_label)
# Out:
# player1
# player2

# %%
for player in list(players.values()):
    player_label = f"player{player['position']}"
    print(f"--------- {player_label} ---------")

    for bet in player['bets']:
        bet_label = f"{player_label}_bet_{bet['stage']}"
        print(f"{bet_label}: {bet['actions']}")
# Out:
# --------- player1 ---------
# player1_bet_p: Bf
# player1_bet_f: -
# player1_bet_t: -
# player1_bet_r: -
# --------- player2 ---------
# player2_bet_p: B
# player2_bet_f: -
# player2_bet_t: -
# player2_bet_r: -

# %%
second_obj
# Out:
# {'_id': 'holdem3_199505_800160788',
#  'board': ['Jc', 'Qs', '6s', '6d'],
#  'dealer': 1,
#  'game': 'holdem3',
#  'hand_num': 2,
#  'num_players': 2,
#  'players': {'A8': {'total_bet': 250,
#    'bankroll': 8346,
#    'bets': [{'actions': 'Br', 'stage': 'p'},
#     {'actions': 'b', 'stage': 'f'},
#     {'actions': 'bf', 'stage': 't'},
#     {'actions': '-', 'stage': 'r'}],
#    'pocket_cards': [],
#    'position': 2,
#    'total_win': 0},
#   'Schween': {'total_bet': 350,
#    'bankroll': 8060,
#    'bets': [{'actions': 'Bcc', 'stage': 'p'},
#     {'actions': 'kc', 'stage': 'f'},
#     {'actions': 'kr', 'stage': 't'},
#     {'actions': '-', 'stage': 'r'}],
#    'pocket_cards': [],
#    'position': 1,
#    'total_win': 600}},
#  'pots': [{'num_players': 2, 'stage': 'f', 'size': 200},
#   {'num_players': 2, 'stage': 't', 'size': 300},
#   {'num_players': 0, 'stage': 'r', 'size': 0},
#   {'num_players': 1, 'stage': 's', 'size': 600}]}

# %%
for pot in second_obj['pots']:
    pot_size_label = f"pot_size_{pot['stage']}"
    pot_players_num_label = f"pot_players_num_{pot['stage']}"
    print(f"{pot_size_label}: {pot['size']}")
    print(f"{pot_players_num_label}: {pot['num_players']}")
    print('-'*20)
# Out:
# pot_size_f: 200
# pot_players_num_f: 2
# --------------------
# pot_size_t: 300
# pot_players_num_t: 2
# --------------------
# pot_size_r: 0
# pot_players_num_r: 0
# --------------------
# pot_size_s: 600
# pot_players_num_s: 1
# --------------------

# %%
for player in list(players.values()):
    player_label = f"player{player['position']}"
    print(len(player['pocket_cards']))
    print(f"{player_label}: {normalize_cards_list(player['pocket_cards'], cards_num=2)}")
# Out:
# 0
# player1: ['-', '-']
# 0
# player2: ['-', '-']

# %%
stages = {
    "p": "preflop",
    "f": "flop",
    "t": "turn",
    "r": "river",
    "s": "showdown"
}

# %%
def process_bets(player_label:str, bets_list:list[dict], stages:dict):
    bets_ = {}
    for bet in bets_list:
        stage_verbose_name = stages[bet['stage']]
        bets_[f"{player_label}_bet_{stage_verbose_name}"] = bet['actions']
    return bets_

# %%
def process_players(player_label: str, player_object: dict, stages:dict):
    bets = process_bets(player_label, player_object['bets'], stages)
    result = {
        f"{player_label}_total_bet": player_object['total_bet'],
        f"{player_label}_bankroll": player_object['bankroll'],
        f"{player_label}_total_win": player_object['total_win']
    }
    
    result.update(bets)
    
    return result

# %%
process_players(*list(second_obj['players'].items())[0], stages)
# Out:
# {'A8_total_bet': 250,
#  'A8_bankroll': 8346,
#  'A8_total_win': 0,
#  'A8_bet_preflop': 'Br',
#  'A8_bet_flop': 'b',
#  'A8_bet_turn': 'bf',
#  'A8_bet_river': '-'}

# %%
def process_pots(pots_list:list[dict], sstages:dict):
    result = {}
    for pot in pots_list:
        stage_verbose_name = stages[pot['stage']]
        result[f"pot_players_num_{stage_verbose_name}"] = pot['num_players'] 
        result[f"pot_size_{stage_verbose_name}"] = pot['size']
    return result

# %%
process_pots(second_obj['pots'], stages)
# Out:
# {'pot_players_num_flop': 2,
#  'pot_size_flop': 200,
#  'pot_players_num_turn': 2,
#  'pot_size_turn': 300,
#  'pot_players_num_river': 0,
#  'pot_size_river': 0,
#  'pot_players_num_showdown': 1,
#  'pot_size_showdown': 600}

# %%
def process_pocket_cards(player_label: str, cards: list):
    return {f"{player_label}_pocket_card{i+1}": card for i, card in enumerate(cards)}

# %%
def holdem_version_extractor(game_name:str):
    match = re.search(r"holdem(\d+)", game_name)
    game_version = int(match.group(1)) if match else 0
    return game_version

# %%
def process_row(dict_row, stages:dict):
    result = {
        "game_id": holdem_version_extractor(dict_row["game"]),
        "dealer_id": dict_row["dealer"],
        "players_num": dict_row["num_players"]
    }
    year, month, timestamp = extract_date(dict_row, '_id')
    result["year"], result["month"], result["timestamp"] = year, month, timestamp
    board = normalize_cards_list(dict_row['board'], cards_num=5)
    for i, card in enumerate(board):
        result[f"board_card_{i+1}"] = card
    for player_name, player_info in dict_row["players"].items():
        pocket_cards = player_info["pocket_cards"]
        normalized_pocket_cards = normalize_cards_list(pocket_cards, cards_num=2)
        player_label = f"player{player_info['position']}"
        processed_player = process_players(player_label, player_info, stages)
        processed_player.update(process_pocket_cards(player_label, normalized_pocket_cards))
        result.update(processed_player)
        result[f"player{player_info['position']}_name"] = player_name
    pots = process_pots(dict_row['pots'], stages)
    result.update(pots)
    return result

# %%
print(process_row(second_obj, stages))
# Out:
# {'game_id': 3, 'dealer_id': 1, 'players_num': 2, 'year': '1995', 'month': '05', 'timestamp': '800160788', 'board_card_1': 'Jc', 'board_card_2': 'Qs', 'board_card_3': '6s', 'board_card_4': '6d', 'board_card_5': '-', 'player2_total_bet': 250, 'player2_bankroll': 8346, 'player2_total_win': 0, 'player2_bet_preflop': 'Br', 'player2_bet_flop': 'b', 'player2_bet_turn': 'bf', 'player2_bet_river': '-', 'player2_pocket_card1': '-', 'player2_pocket_card2': '-', 'player2_name': 'A8', 'player1_total_bet': 350, 'player1_bankroll': 8060, 'player1_total_win': 600, 'player1_bet_preflop': 'Bcc', 'player1_bet_flop': 'kc', 'player1_bet_turn': 'kr', 'player1_bet_river': '-', 'player1_pocket_card1': '-', 'player1_pocket_card2': '-', 'player1_name': 'Schween', 'pot_players_num_flop': 2, 'pot_size_flop': 200, 'pot_players_num_turn': 2, 'pot_size_turn': 300, 'pot_players_num_river': 0, 'pot_size_river': 0, 'pot_players_num_showdown': 1, 'pot_size_showdown': 600}

# %%
processed_data = [process_row(row, stages) for row in data]

# %%
processed_data[1:3]
# Out:
# [{'game_id': 3,
#   'dealer_id': 1,
#   'players_num': 2,
#   'year': '1995',
#   'month': '05',
#   'timestamp': '800160788',
#   'board_card_1': 'Jc',
#   'board_card_2': 'Qs',
#   'board_card_3': '6s',
#   'board_card_4': '6d',
#   'board_card_5': '-',
#   'player2_total_bet': 250,
#   'player2_bankroll': 8346,
#   'player2_total_win': 0,
#   'player2_bet_preflop': 'Br',
#   'player2_bet_flop': 'b',
#   'player2_bet_turn': 'bf',
#   'player2_bet_river': '-',
#   'player2_pocket_card1': '-',
#   'player2_pocket_card2': '-',
#   'player2_name': 'A8',
#   'player1_total_bet': 350,
#   'player1_bankroll': 8060,
#   'player1_total_win': 600,
#   'player1_bet_preflop': 'Bcc',
#   'player1_bet_flop': 'kc',
#   'player1_bet_turn': 'kr',
#   'player1_bet_river': '-',
#   'player1_pocket_card1': '-',
#   'player1_pocket_card2': '-',
#   'player1_name': 'Schween',
#   'pot_players_num_flop': 2,
#   'pot_size_flop': 200,
#   'pot_players_num_turn': 2,
#   'pot_size_turn': 300,
#   'pot_players_num_river': 0,
#   'pot_size_river': 0,
#   'pot_players_num_showdown': 1,
#   'pot_size_showdown': 600},
#  {'game_id': 3,
#   'dealer_id': 1,
#   'players_num': 2,
#   'year': '1995',
#   'month': '05',
#   'timestamp': '800160827',
#   'board_card_1': '9h',
#   'board_card_2': '7s',
#   'board_card_3': 'Qc',
#   'board_card_4': '-',
#   'board_card_5': '-',
#   'player1_total_bet': 150,
#   'player1_bankroll': 8096,
#   'player1_total_win': 250,
#   'player1_bet_preflop': 'Br',
#   'player1_bet_flop': 'b',
#   'player1_bet_turn': '-',
#   'player1_bet_river': '-',
#   'player1_pocket_card1': '-',
#   'player1_pocket_card2': '-',
#   'player1_name': 'A8',
#   'player2_total_bet': 100,
#   'player2_bankroll': 8310,
#   'player2_total_win': 0,
#   'player2_bet_preflop': 'Bc',
#   'player2_bet_flop': 'f',
#   'player2_bet_turn': '-',
#   'player2_bet_river': '-',
#   'player2_pocket_card1': '-',
#   'player2_pocket_card2': '-',
#   'player2_name': 'Schween',
#   'pot_players_num_flop': 2,
#   'pot_size_flop': 200,
#   'pot_players_num_turn': 0,
#   'pot_size_turn': 0,
#   'pot_players_num_river': 0,
#   'pot_size_river': 0,
#   'pot_players_num_showdown': 1,
#   'pot_size_showdown': 250}]

# %%
df = pd.DataFrame(processed_data)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    game_id  dealer_id  players_num  year month  timestamp board_card_1  \
# 0        3          1            2  1995    05  800160769            -
# 1        3          1            2  1995    05  800160788           Jc
# 2        3          1            2  1995    05  800160827           9h
# 3        3          1            2  1995    05  800160846           Qh
# 4        3          1            2  1995    05  800160880           As
#
#   board_card_2 board_card_3 board_card_4 board_card_5  player1_total_bet  \
# 0            -            -            -            -                 25
# 1           Qs           6s           6d            -                350
# 2           7s           Qc            -            -                150
# 3           6s           3s            -            -                150
# 4           3c           6s            -            -                250
#
#    player1_bankroll  player1_total_win player1_bet_preflop player1_bet_flop  \
# 0              8371                  0                  Bf                -
# 1              8060                600                 Bcc               kc
# 2              8096                250                  Br                b
# 3              8210                  0                 Brc               kf
# 4              8346                450                  Br               br
#
#   player1_bet_turn player1_bet_river player1_pocket_card1  \
# 0                -                 -                    -
# 1               kr                 -                    -
# 2                -                 -                    -
# 3                -                 -                    -
# 4                -                 -                    -
#
#   player1_pocket_card2 player1_name  player2_total_bet  player2_bankroll  \
# 0                    -           A8                 50              8035
# 1                    -      Schween                250              8346
# 2                    -           A8                100              8310
# 3                    -      Schween                200              8196
# 4                    -           A8                200              8060
#
#    player2_total_win player2_bet_preflop player2_bet_flop player2_bet_turn  \
# 0                 75                   B                -                -
# 1                  0                  Br                b               bf
# 2                  0                  Bc                f                -
# 3                350                  Br                b                -
# 4                  0                  Bc               rf                -
#
#   player2_bet_river player2_pocket_card1 player2_pocket_card2 player2_name  \
# 0                 -                    -                    -      Schween
# 1                 -                    -                    -           A8
# 2                 -                    -                    -      Schween
# 3                 -                    -                    -           A8
# 4                 -                    -                    -      Schween
#
#    pot_players_num_flop  pot_size_flop  pot_players_num_turn  pot_size_turn  \
# 0                     0              0                     0              0
# 1                     2            200                     2            300
# 2                     2            200                     0              0
# 3                     2            300                     0              0
# 4                     2            200                     0              0
#
#    pot_players_num_river  pot_size_river  pot_players_num_showdown  \
# 0                      0               0                         1
# 1                      0               0                         1
# 2                      0               0                         1
# 3                      0               0                         1
# 4                      0               0                         1
#
#    pot_size_showdown  player3_total_bet  player3_bankroll  player3_total_win  \
# 0                 75                NaN               NaN                NaN
# 1                600                NaN               NaN                NaN
# 2                250                NaN               NaN                NaN
# 3                350                NaN               NaN                NaN
# 4                450                NaN               NaN                NaN
#
#   player3_bet_preflop player3_bet_flop player3_bet_turn player3_bet_river  \
# 0                 NaN              NaN              NaN               NaN
# 1                 NaN              NaN              NaN               NaN
# 2                 NaN              NaN              NaN               NaN
# 3                 NaN              NaN              NaN               NaN
# 4                 NaN              NaN              NaN               NaN
#
#   player3_pocket_card1 player3_pocket_card2 player3_name  player4_total_bet  \
# 0                  NaN                  NaN          NaN                NaN
# 1                  NaN                  NaN          NaN                NaN
# 2                  NaN                  NaN          NaN                NaN
# 3                  NaN                  NaN          NaN                NaN
# 4                  NaN                  NaN          NaN                NaN
#
#    player4_bankroll  player4_total_win player4_bet_preflop player4_bet_flop  \
# 0               NaN                NaN                 NaN              NaN
# 1               NaN                NaN                 NaN              NaN
# 2               NaN                NaN                 NaN              NaN
# 3               NaN                NaN                 NaN              NaN
# 4               NaN                NaN                 NaN              NaN
#
#   player4_bet_turn player4_bet_river player4_pocket_card1  \
# 0              NaN               NaN                  NaN
# 1              NaN               NaN                  NaN
# 2              NaN               NaN                  NaN
# 3              NaN               NaN                  NaN
# 4              NaN               NaN                  NaN
#
#   player4_pocket_card2 player4_name  player5_total_bet  player5_bankroll  \
# 0                  NaN          NaN                NaN               NaN
# 1                  NaN          NaN                NaN               NaN
# 2                  NaN          NaN                NaN               NaN
# 3                  NaN          NaN                NaN               NaN
# 4                  NaN          NaN                NaN               NaN
#
#    player5_total_win player5_bet_preflop player5_bet_flop player5_bet_turn  \
# 0                NaN                 NaN              NaN              NaN
# 1                NaN                 NaN              NaN              NaN
# 2                NaN                 NaN              NaN              NaN
# 3                NaN                 NaN              NaN              NaN
# 4                NaN                 NaN              NaN              NaN
#
#   player5_bet_river player5_pocket_card1 player5_pocket_card2 player5_name  \
# 0               NaN                  NaN                  NaN          NaN
# 1               NaN                  NaN                  NaN          NaN
# 2               NaN                  NaN                  NaN          NaN
# 3               NaN                  NaN                  NaN          NaN
# 4               NaN                  NaN                  NaN          NaN
#
#    player6_total_bet  player6_bankroll  player6_total_win player6_bet_preflop  \
# 0                NaN               NaN                NaN                 NaN
# 1                NaN               NaN                NaN                 NaN
# 2                NaN               NaN                NaN                 NaN
# 3                NaN               NaN                NaN                 NaN
# 4                NaN               NaN                NaN                 NaN
#
#   player6_bet_flop player6_bet_turn player6_bet_river player6_pocket_card1  \
# 0              NaN              NaN               NaN                  NaN
# 1              NaN              NaN               NaN                  NaN
# 2              NaN              NaN               NaN                  NaN
# 3              NaN              NaN               NaN                  NaN
# 4              NaN              NaN               NaN                  NaN
#
#   player6_pocket_card2 player6_name  player7_total_bet  player7_bankroll  \
# 0                  NaN          NaN                NaN               NaN
# 1                  NaN          NaN                NaN               NaN
# 2                  NaN          NaN                NaN               NaN
# 3                  NaN          NaN                NaN               NaN
# 4                  NaN          NaN                NaN               NaN
#
#    player7_total_win player7_bet_preflop player7_bet_flop player7_bet_turn  \
# 0                NaN                 NaN              NaN              NaN
# 1                NaN                 NaN              NaN              NaN
# 2                NaN                 NaN              NaN              NaN
# 3                NaN                 NaN              NaN              NaN
# 4                NaN                 NaN              NaN              NaN
#
#   player7_bet_river player7_pocket_card1 player7_pocket_card2 player7_name  \
# 0               NaN                  NaN                  NaN          NaN
# 1               NaN                  NaN                  NaN          NaN
# 2               NaN                  NaN                  NaN          NaN
# 3               NaN                  NaN                  NaN          NaN
# 4               NaN                  NaN                  NaN          NaN
#
#    player8_total_bet  player8_bankroll  player8_total_win player8_bet_preflop  \
# 0                NaN               NaN                NaN                 NaN
# 1                NaN               NaN                NaN                 NaN
# 2                NaN               NaN                NaN                 NaN
# 3                NaN               NaN                NaN                 NaN
# 4                NaN               NaN                NaN                 NaN
#
#   player8_bet_flop player8_bet_turn player8_bet_river player8_pocket_card1  \
# 0              NaN              NaN               NaN                  NaN
# 1              NaN              NaN               NaN                  NaN
# 2              NaN              NaN               NaN                  NaN
# 3              NaN              NaN               NaN                  NaN
# 4              NaN              NaN               NaN                  NaN
#
#   player8_pocket_card2 player8_name  player9_total_bet  player9_bankroll  \
# 0                  NaN          NaN                NaN               NaN
# 1                  NaN          NaN                NaN               NaN
# 2                  NaN          NaN                NaN               NaN
# 3                  NaN          NaN                NaN               NaN
# 4                  NaN          NaN                NaN               NaN
#
#    player9_total_win player9_bet_preflop player9_bet_flop player9_bet_turn  \
# 0                NaN                 NaN              NaN              NaN
# 1                NaN                 NaN              NaN              NaN
# 2                NaN                 NaN              NaN              NaN
# 3                NaN                 NaN              NaN              NaN
# 4                NaN                 NaN              NaN              NaN
#
#   player9_bet_river player9_pocket_card1 player9_pocket_card2 player9_name  \
# 0               NaN                  NaN                  NaN          NaN
# 1               NaN                  NaN                  NaN          NaN
# 2               NaN                  NaN                  NaN          NaN
# 3               NaN                  NaN                  NaN          NaN
# 4               NaN                  NaN                  NaN          NaN
#
#    player10_total_bet  player10_bankroll  player10_total_win  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
#
#   player10_bet_preflop player10_bet_flop player10_bet_turn player10_bet_river  \
# 0                  NaN               NaN               NaN                NaN
# 1                  NaN               NaN               NaN                NaN
# 2                  NaN               NaN               NaN                NaN
# 3                  NaN               NaN               NaN                NaN
# 4                  NaN               NaN               NaN                NaN
#
#   player10_pocket_card1 player10_pocket_card2 player10_name  \
# 0                   NaN                   NaN           NaN
# 1                   NaN                   NaN           NaN
# 2                   NaN                   NaN           NaN
# 3                   NaN                   NaN           NaN
# 4                   NaN                   NaN           NaN
#
#    player11_total_bet  player11_bankroll  player11_total_win  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
#
#   player11_bet_preflop player11_bet_flop player11_bet_turn player11_bet_river  \
# 0                  NaN               NaN               NaN                NaN
# 1                  NaN               NaN               NaN                NaN
# 2                  NaN               NaN               NaN                NaN
# 3                  NaN               NaN               NaN                NaN
# 4                  NaN               NaN               NaN                NaN
#
#   player11_pocket_card1 player11_pocket_card2 player11_name  \
# 0                   NaN                   NaN           NaN
# 1                   NaN                   NaN           NaN
# 2                   NaN                   NaN           NaN
# 3                   NaN                   NaN           NaN
# 4                   NaN                   NaN           NaN
#
#    player12_total_bet  player12_bankroll  player12_total_win  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
#
#   player12_bet_preflop player12_bet_flop player12_bet_turn player12_bet_river  \
# 0                  NaN               NaN               NaN                NaN
# 1                  NaN               NaN               NaN                NaN
# 2                  NaN               NaN               NaN                NaN
# 3                  NaN               NaN               NaN                NaN
# 4                  NaN               NaN               NaN                NaN
#
#   player12_pocket_card1 player12_pocket_card2 player12_name
# 0                   NaN                   NaN           NaN
# 1                   NaN                   NaN           NaN
# 2                   NaN                   NaN           NaN
# 3                   NaN                   NaN           NaN
# 4                   NaN                   NaN           NaN

# %%
df.shape
# Out:
# (439682, 139)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439682 entries, 0 to 439681
# Data columns (total 139 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    game_id                   int64
#  1    dealer_id                 int64
#  2    players_num               int64
#  3    year                      object
#  4    month                     object
#  5    timestamp                 object
#  6    board_card_1              object
#  7    board_card_2              object
#  8    board_card_3              object
#  9    board_card_4              object
#  10   board_card_5              object
#  11   player1_total_bet         int64
#  12   player1_bankroll          int64
#  13   player1_total_win         int64
#  14   player1_bet_preflop       object
#  15   player1_bet_flop          object
#  16   player1_bet_turn          object
#  17   player1_bet_river         object
#  18   player1_pocket_card1      object
#  19   player1_pocket_card2      object
#  20   player1_name              object
#  21   player2_total_bet         int64
#  22   player2_bankroll          int64
#  23   player2_total_win         int64
#  24   player2_bet_preflop       object
#  25   player2_bet_flop          object
#  26   player2_bet_turn          object
#  27   player2_bet_river         object
#  28   player2_pocket_card1      object
#  29   player2_pocket_card2      object
#  30   player2_name              object
#  31   pot_players_num_flop      int64
#  32   pot_size_flop             int64
#  33   pot_players_num_turn      int64
#  34   pot_size_turn             int64
#  35   pot_players_num_river     int64
#  36   pot_size_river            int64
#  37   pot_players_num_showdown  int64
#  38   pot_size_showdown         int64
#  39   player3_total_bet         float64
#  40   player3_bankroll          float64
#  41   player3_total_win         float64
#  42   player3_bet_preflop       object
#  43   player3_bet_flop          object
#  44   player3_bet_turn          object
#  45   player3_bet_river         object
#  46   player3_pocket_card1      object
#  47   player3_pocket_card2      object
#  48   player3_name              object
#  49   player4_total_bet         float64
#  50   player4_bankroll          float64
#  51   player4_total_win         float64
#  52   player4_bet_preflop       object
#  53   player4_bet_flop          object
#  54   player4_bet_turn          object
#  55   player4_bet_river         object
#  56   player4_pocket_card1      object
#  57   player4_pocket_card2      object
#  58   player4_name              object
#  59   player5_total_bet         float64
#  60   player5_bankroll          float64
#  61   player5_total_win         float64
#  62   player5_bet_preflop       object
#  63   player5_bet_flop          object
#  64   player5_bet_turn          object
#  65   player5_bet_river         object
#  66   player5_pocket_card1      object
#  67   player5_pocket_card2      object
#  68   player5_name              object
#  69   player6_total_bet         float64
#  70   player6_bankroll          float64
#  71   player6_total_win         float64
#  72   player6_bet_preflop       object
#  73   player6_bet_flop          object
#  74   player6_bet_turn          object
#  75   player6_bet_river         object
#  76   player6_pocket_card1      object
#  77   player6_pocket_card2      object
#  78   player6_name              object
#  79   player7_total_bet         float64
#  80   player7_bankroll          float64
#  81   player7_total_win         float64
#  82   player7_bet_preflop       object
#  83   player7_bet_flop          object
#  84   player7_bet_turn          object
#  85   player7_bet_river         object
#  86   player7_pocket_card1      object
#  87   player7_pocket_card2      object
#  88   player7_name              object
#  89   player8_total_bet         float64
#  90   player8_bankroll          float64
#  91   player8_total_win         float64
#  92   player8_bet_preflop       object
#  93   player8_bet_flop          object
#  94   player8_bet_turn          object
#  95   player8_bet_river         object
#  96   player8_pocket_card1      object
#  97   player8_pocket_card2      object
#  98   player8_name              object
#  99   player9_total_bet         float64
#  100  player9_bankroll          float64
#  101  player9_total_win         float64
#  102  player9_bet_preflop       object
#  103  player9_bet_flop          object
#  104  player9_bet_turn          object
#  105  player9_bet_river         object
#  106  player9_pocket_card1      object
#  107  player9_pocket_card2      object
#  108  player9_name              object
#  109  player10_total_bet        float64
#  110  player10_bankroll         float64
#  111  player10_total_win        float64
#  112  player10_bet_preflop      object
#  113  player10_bet_flop         object
#  114  player10_bet_turn         object
#  115  player10_bet_river        object
#  116  player10_pocket_card1     object
#  117  player10_pocket_card2     object
#  118  player10_name             object
#  119  player11_total_bet        float64
#  120  player11_bankroll         float64
#  121  player11_total_win        float64
#  122  player11_bet_preflop      object
#  123  player11_bet_flop         object
#  124  player11_bet_turn         object
#  125  player11_bet_river        object
#  126  player11_pocket_card1     object
#  127  player11_pocket_card2     object
#  128  player11_name             object
#  129  player12_total_bet        float64
#  130  player12_bankroll         float64
#  131  player12_total_win        float64
#  132  player12_bet_preflop      object
#  133  player12_bet_flop         object
#  134  player12_bet_turn         object
#  135  player12_bet_river        object
#  136  player12_pocket_card1     object
#  137  player12_pocket_card2     object
#  138  player12_name             object
# dtypes: float64(30), int64(17), object(92)
# memory usage: 466.3+ MB

# %%
df.columns
# Out:
# Index(['game_id', 'dealer_id', 'players_num', 'year', 'month', 'timestamp',
#        'board_card_1', 'board_card_2', 'board_card_3', 'board_card_4',
#        ...
#        'player12_total_bet', 'player12_bankroll', 'player12_total_win',
#        'player12_bet_preflop', 'player12_bet_flop', 'player12_bet_turn',
#        'player12_bet_river', 'player12_pocket_card1', 'player12_pocket_card2',
#        'player12_name'],
#       dtype='object', length=139)

# %%
(
    df.
    filter(regex='player\\d+_total_bet').
    isnull().sum().to_frame().
    rename(columns={0: "missing_count"}).
    assign(data_count = lambda df_: df.shape[0] - df_.missing_count).
    assign(missing_ratio = lambda df_: round(df_.missing_count/df.shape[0], 3))
)
# Out:
#                     missing_count  data_count  missing_ratio
# player1_total_bet               0      439682          0.000
# player2_total_bet               0      439682          0.000
# player3_total_bet          207279      232403          0.471
# player4_total_bet          312658      127024          0.711
# player5_total_bet          367543       72139          0.836
# player6_total_bet          397983       41699          0.905
# player7_total_bet          416035       23647          0.946
# player8_total_bet          427030       12652          0.971
# player9_total_bet          433701        5981          0.986
# player10_total_bet         437173        2509          0.994
# player11_total_bet         439524         158          1.000
# player12_total_bet         439648          34          1.000

# %%
pattern = r"player\d+.+|board_card_\d+"
filtered_df = df.filter(regex=pattern)
filtered_df
# Out:
#        board_card_1 board_card_2 board_card_3 board_card_4 board_card_5  \
# 0                 -            -            -            -            -
# 1                Jc           Qs           6s           6d            -
# 2                9h           7s           Qc            -            -
# 3                Qh           6s           3s            -            -
# 4                As           3c           6s            -            -
# ...             ...          ...          ...          ...          ...
# 439677            -            -            -            -            -
# 439678           4h           Ts           2h           Qc           2d
# 439679           4d           3h           5d           5h           7c
# 439680           6h           9s           4d           Qh           6s
# 439681           Ac           Qh           9d           6c           3d
#
#         player1_total_bet  player1_bankroll  player1_total_win  \
# 0                      25              8371                  0
# 1                     350              8060                600
# 2                     150              8096                250
# 3                     150              8210                  0
# 4                     250              8346                450
# ...                   ...               ...                ...
# 439677                 25              6115                 75
# 439678               2050              5846                  0
# 439679                350             11390                600
# 439680                 50              3546                  0
# 439681               3596             11690               7092
#
#        player1_bet_preflop player1_bet_flop player1_bet_turn  \
# 0                       Bf                -                -
# 1                      Bcc               kc               kr
# 2                       Br                b                -
# 3                      Brc               kf                -
# 4                       Br               br                -
# ...                    ...              ...              ...
# 439677                   B                -                -
# 439678                 Brc                k                k
# 439679                  Bc                k                k
# 439680                  Bc                k                k
# 439681                  Bc               br               br
#
#        player1_bet_river player1_pocket_card1 player1_pocket_card2  \
# 0                      -                    -                    -
# 1                      -                    -                    -
# 2                      -                    -                    -
# 3                      -                    -                    -
# 4                      -                    -                    -
# ...                  ...                  ...                  ...
# 439677                 -                    -                    -
# 439678        brrrrrrrrr                   3c                   8s
# 439679                br                    -                    -
# 439680                kf                    -                    -
# 439681  brrrrrrrrrrrrrrr                   Qd                   7s
#
#        player1_name  player2_total_bet  player2_bankroll  player2_total_win  \
# 0                A8                 50              8035                 75
# 1           Schween                250              8346                  0
# 2                A8                100              8310                  0
# 3           Schween                200              8196                350
# 4                A8                200              8060                  0
# ...             ...                ...               ...                ...
# 439677     fatpat55                 50              8445                  0
# 439678     fatpat55               2050              9340               4100
# 439679      rivrgod                250              3796                  0
# 439680     fatpat55                150             11640                200
# 439681      rivrgod               3496              3496                  0
#
#        player2_bet_preflop player2_bet_flop player2_bet_turn  \
# 0                        B                -                -
# 1                       Br                b               bf
# 2                       Bc                f                -
# 3                       Br                b                -
# 4                       Bc               rf                -
# ...                    ...              ...              ...
# 439677                  BQ                -                -
# 439678                  Br                k                k
# 439679                  Bk                k                k
# 439680                  Bk                k                k
# 439681                  Bk               rc               rc
#
#        player2_bet_river player2_pocket_card1 player2_pocket_card2  \
# 0                      -                    -                    -
# 1                      -                    -                    -
# 2                      -                    -                    -
# 3                      -                    -                    -
# 4                      -                    -                    -
# ...                  ...                  ...                  ...
# 439677                 -                    -                    -
# 439678        rrrrrrrrrc                   Qh                   8c
# 439679                rf                    -                    -
# 439680                 b                    -                    -
# 439681  rrrrrrrrrrrrrrrA                   8c                   7d
#
#        player2_name  player3_total_bet  player3_bankroll  player3_total_win  \
# 0           Schween                NaN               NaN                NaN
# 1                A8                NaN               NaN                NaN
# 2           Schween                NaN               NaN                NaN
# 3                A8                NaN               NaN                NaN
# 4           Schween                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677       zeigen                NaN               NaN                NaN
# 439678      rivrgod                NaN               NaN                NaN
# 439679     fatpat55                NaN               NaN                NaN
# 439680      rivrgod                NaN               NaN                NaN
# 439681     fatpat55                NaN               NaN                NaN
#
#        player3_bet_preflop player3_bet_flop player3_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player3_bet_river player3_pocket_card1 player3_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player3_name  player4_total_bet  player4_bankroll  player4_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player4_bet_preflop player4_bet_flop player4_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player4_bet_river player4_pocket_card1 player4_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player4_name  player5_total_bet  player5_bankroll  player5_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player5_bet_preflop player5_bet_flop player5_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player5_bet_river player5_pocket_card1 player5_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player5_name  player6_total_bet  player6_bankroll  player6_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player6_bet_preflop player6_bet_flop player6_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player6_bet_river player6_pocket_card1 player6_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player6_name  player7_total_bet  player7_bankroll  player7_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player7_bet_preflop player7_bet_flop player7_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player7_bet_river player7_pocket_card1 player7_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player7_name  player8_total_bet  player8_bankroll  player8_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player8_bet_preflop player8_bet_flop player8_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player8_bet_river player8_pocket_card1 player8_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player8_name  player9_total_bet  player9_bankroll  player9_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player9_bet_preflop player9_bet_flop player9_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player9_bet_river player9_pocket_card1 player9_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player9_name  player10_total_bet  player10_bankroll  \
# 0               NaN                 NaN                NaN
# 1               NaN                 NaN                NaN
# 2               NaN                 NaN                NaN
# 3               NaN                 NaN                NaN
# 4               NaN                 NaN                NaN
# ...             ...                 ...                ...
# 439677          NaN                 NaN                NaN
# 439678          NaN                 NaN                NaN
# 439679          NaN                 NaN                NaN
# 439680          NaN                 NaN                NaN
# 439681          NaN                 NaN                NaN
#
#         player10_total_win player10_bet_preflop player10_bet_flop  \
# 0                      NaN                  NaN               NaN
# 1                      NaN                  NaN               NaN
# 2                      NaN                  NaN               NaN
# 3                      NaN                  NaN               NaN
# 4                      NaN                  NaN               NaN
# ...                    ...                  ...               ...
# 439677                 NaN                  NaN               NaN
# 439678                 NaN                  NaN               NaN
# 439679                 NaN                  NaN               NaN
# 439680                 NaN                  NaN               NaN
# 439681                 NaN                  NaN               NaN
#
#        player10_bet_turn player10_bet_river player10_pocket_card1  \
# 0                    NaN                NaN                   NaN
# 1                    NaN                NaN                   NaN
# 2                    NaN                NaN                   NaN
# 3                    NaN                NaN                   NaN
# 4                    NaN                NaN                   NaN
# ...                  ...                ...                   ...
# 439677               NaN                NaN                   NaN
# 439678               NaN                NaN                   NaN
# 439679               NaN                NaN                   NaN
# 439680               NaN                NaN                   NaN
# 439681               NaN                NaN                   NaN
#
#        player10_pocket_card2 player10_name  player11_total_bet  \
# 0                        NaN           NaN                 NaN
# 1                        NaN           NaN                 NaN
# 2                        NaN           NaN                 NaN
# 3                        NaN           NaN                 NaN
# 4                        NaN           NaN                 NaN
# ...                      ...           ...                 ...
# 439677                   NaN           NaN                 NaN
# 439678                   NaN           NaN                 NaN
# 439679                   NaN           NaN                 NaN
# 439680                   NaN           NaN                 NaN
# 439681                   NaN           NaN                 NaN
#
#         player11_bankroll  player11_total_win player11_bet_preflop  \
# 0                     NaN                 NaN                  NaN
# 1                     NaN                 NaN                  NaN
# 2                     NaN                 NaN                  NaN
# 3                     NaN                 NaN                  NaN
# 4                     NaN                 NaN                  NaN
# ...                   ...                 ...                  ...
# 439677                NaN                 NaN                  NaN
# 439678                NaN                 NaN                  NaN
# 439679                NaN                 NaN                  NaN
# 439680                NaN                 NaN                  NaN
# 439681                NaN                 NaN                  NaN
#
#        player11_bet_flop player11_bet_turn player11_bet_river  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 439677               NaN               NaN                NaN
# 439678               NaN               NaN                NaN
# 439679               NaN               NaN                NaN
# 439680               NaN               NaN                NaN
# 439681               NaN               NaN                NaN
#
#        player11_pocket_card1 player11_pocket_card2 player11_name  \
# 0                        NaN                   NaN           NaN
# 1                        NaN                   NaN           NaN
# 2                        NaN                   NaN           NaN
# 3                        NaN                   NaN           NaN
# 4                        NaN                   NaN           NaN
# ...                      ...                   ...           ...
# 439677                   NaN                   NaN           NaN
# 439678                   NaN                   NaN           NaN
# 439679                   NaN                   NaN           NaN
# 439680                   NaN                   NaN           NaN
# 439681                   NaN                   NaN           NaN
#
#         player12_total_bet  player12_bankroll  player12_total_win  \
# 0                      NaN                NaN                 NaN
# 1                      NaN                NaN                 NaN
# 2                      NaN                NaN                 NaN
# 3                      NaN                NaN                 NaN
# 4                      NaN                NaN                 NaN
# ...                    ...                ...                 ...
# 439677                 NaN                NaN                 NaN
# 439678                 NaN                NaN                 NaN
# 439679                 NaN                NaN                 NaN
# 439680                 NaN                NaN                 NaN
# 439681                 NaN                NaN                 NaN
#
#        player12_bet_preflop player12_bet_flop player12_bet_turn  \
# 0                       NaN               NaN               NaN
# 1                       NaN               NaN               NaN
# 2                       NaN               NaN               NaN
# 3                       NaN               NaN               NaN
# 4                       NaN               NaN               NaN
# ...                     ...               ...               ...
# 439677                  NaN               NaN               NaN
# 439678                  NaN               NaN               NaN
# 439679                  NaN               NaN               NaN
# 439680                  NaN               NaN               NaN
# 439681                  NaN               NaN               NaN
#
#        player12_bet_river player12_pocket_card1 player12_pocket_card2  \
# 0                     NaN                   NaN                   NaN
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# ...                   ...                   ...                   ...
# 439677                NaN                   NaN                   NaN
# 439678                NaN                   NaN                   NaN
# 439679                NaN                   NaN                   NaN
# 439680                NaN                   NaN                   NaN
# 439681                NaN                   NaN                   NaN
#
#        player12_name
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 439677           NaN
# 439678           NaN
# 439679           NaN
# 439680           NaN
# 439681           NaN
#
# [439682 rows x 125 columns]

# %%
df[df.players_num == 2]
# Out:
#         game_id  dealer_id  players_num  year month  timestamp board_card_1  \
# 0             3          1            2  1995    05  800160769            -
# 1             3          1            2  1995    05  800160788           Jc
# 2             3          1            2  1995    05  800160827           9h
# 3             3          1            2  1995    05  800160846           Qh
# 4             3          1            2  1995    05  800160880           As
# ...         ...        ...          ...   ...   ...        ...          ...
# 439677        3          1            2  2001    08  998722150            -
# 439678        3          1            2  2001    08  998733998           4h
# 439679        3          1            2  2001    08  998734040           4d
# 439680        3          1            2  2001    08  998734063           6h
# 439681        3          1            2  2001    08  998734076           Ac
#
#        board_card_2 board_card_3 board_card_4 board_card_5  player1_total_bet  \
# 0                 -            -            -            -                 25
# 1                Qs           6s           6d            -                350
# 2                7s           Qc            -            -                150
# 3                6s           3s            -            -                150
# 4                3c           6s            -            -                250
# ...             ...          ...          ...          ...                ...
# 439677            -            -            -            -                 25
# 439678           Ts           2h           Qc           2d               2050
# 439679           3h           5d           5h           7c                350
# 439680           9s           4d           Qh           6s                 50
# 439681           Qh           9d           6c           3d               3596
#
#         player1_bankroll  player1_total_win player1_bet_preflop  \
# 0                   8371                  0                  Bf
# 1                   8060                600                 Bcc
# 2                   8096                250                  Br
# 3                   8210                  0                 Brc
# 4                   8346                450                  Br
# ...                  ...                ...                 ...
# 439677              6115                 75                   B
# 439678              5846                  0                 Brc
# 439679             11390                600                  Bc
# 439680              3546                  0                  Bc
# 439681             11690               7092                  Bc
#
#        player1_bet_flop player1_bet_turn player1_bet_river  \
# 0                     -                -                 -
# 1                    kc               kr                 -
# 2                     b                -                 -
# 3                    kf                -                 -
# 4                    br                -                 -
# ...                 ...              ...               ...
# 439677                -                -                 -
# 439678                k                k        brrrrrrrrr
# 439679                k                k                br
# 439680                k                k                kf
# 439681               br               br  brrrrrrrrrrrrrrr
#
#        player1_pocket_card1 player1_pocket_card2 player1_name  \
# 0                         -                    -           A8
# 1                         -                    -      Schween
# 2                         -                    -           A8
# 3                         -                    -      Schween
# 4                         -                    -           A8
# ...                     ...                  ...          ...
# 439677                    -                    -     fatpat55
# 439678                   3c                   8s     fatpat55
# 439679                    -                    -      rivrgod
# 439680                    -                    -     fatpat55
# 439681                   Qd                   7s      rivrgod
#
#         player2_total_bet  player2_bankroll  player2_total_win  \
# 0                      50              8035                 75
# 1                     250              8346                  0
# 2                     100              8310                  0
# 3                     200              8196                350
# 4                     200              8060                  0
# ...                   ...               ...                ...
# 439677                 50              8445                  0
# 439678               2050              9340               4100
# 439679                250              3796                  0
# 439680                150             11640                200
# 439681               3496              3496                  0
#
#        player2_bet_preflop player2_bet_flop player2_bet_turn  \
# 0                        B                -                -
# 1                       Br                b               bf
# 2                       Bc                f                -
# 3                       Br                b                -
# 4                       Bc               rf                -
# ...                    ...              ...              ...
# 439677                  BQ                -                -
# 439678                  Br                k                k
# 439679                  Bk                k                k
# 439680                  Bk                k                k
# 439681                  Bk               rc               rc
#
#        player2_bet_river player2_pocket_card1 player2_pocket_card2  \
# 0                      -                    -                    -
# 1                      -                    -                    -
# 2                      -                    -                    -
# 3                      -                    -                    -
# 4                      -                    -                    -
# ...                  ...                  ...                  ...
# 439677                 -                    -                    -
# 439678        rrrrrrrrrc                   Qh                   8c
# 439679                rf                    -                    -
# 439680                 b                    -                    -
# 439681  rrrrrrrrrrrrrrrA                   8c                   7d
#
#        player2_name  pot_players_num_flop  pot_size_flop  \
# 0           Schween                     0              0
# 1                A8                     2            200
# 2           Schween                     2            200
# 3                A8                     2            300
# 4           Schween                     2            200
# ...             ...                   ...            ...
# 439677       zeigen                     0              0
# 439678      rivrgod                     2            300
# 439679     fatpat55                     2            100
# 439680      rivrgod                     2            100
# 439681     fatpat55                     2            100
#
#         pot_players_num_turn  pot_size_turn  pot_players_num_river  \
# 0                          0              0                      0
# 1                          2            300                      0
# 2                          0              0                      0
# 3                          0              0                      0
# 4                          0              0                      0
# ...                      ...            ...                    ...
# 439677                     0              0                      0
# 439678                     2            300                      2
# 439679                     2            100                      2
# 439680                     2            100                      2
# 439681                     2            400                      2
#
#         pot_size_river  pot_players_num_showdown  pot_size_showdown  \
# 0                    0                         1                 75
# 1                    0                         1                600
# 2                    0                         1                250
# 3                    0                         1                350
# 4                    0                         1                450
# ...                ...                       ...                ...
# 439677               0                         1                 75
# 439678             300                         2               4100
# 439679             100                         1                600
# 439680             100                         1                200
# 439681            1000                         2               7092
#
#         player3_total_bet  player3_bankroll  player3_total_win  \
# 0                     NaN               NaN                NaN
# 1                     NaN               NaN                NaN
# 2                     NaN               NaN                NaN
# 3                     NaN               NaN                NaN
# 4                     NaN               NaN                NaN
# ...                   ...               ...                ...
# 439677                NaN               NaN                NaN
# 439678                NaN               NaN                NaN
# 439679                NaN               NaN                NaN
# 439680                NaN               NaN                NaN
# 439681                NaN               NaN                NaN
#
#        player3_bet_preflop player3_bet_flop player3_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player3_bet_river player3_pocket_card1 player3_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player3_name  player4_total_bet  player4_bankroll  player4_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player4_bet_preflop player4_bet_flop player4_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player4_bet_river player4_pocket_card1 player4_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player4_name  player5_total_bet  player5_bankroll  player5_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player5_bet_preflop player5_bet_flop player5_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player5_bet_river player5_pocket_card1 player5_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player5_name  player6_total_bet  player6_bankroll  player6_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player6_bet_preflop player6_bet_flop player6_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player6_bet_river player6_pocket_card1 player6_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player6_name  player7_total_bet  player7_bankroll  player7_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player7_bet_preflop player7_bet_flop player7_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player7_bet_river player7_pocket_card1 player7_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player7_name  player8_total_bet  player8_bankroll  player8_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player8_bet_preflop player8_bet_flop player8_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player8_bet_river player8_pocket_card1 player8_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player8_name  player9_total_bet  player9_bankroll  player9_total_win  \
# 0               NaN                NaN               NaN                NaN
# 1               NaN                NaN               NaN                NaN
# 2               NaN                NaN               NaN                NaN
# 3               NaN                NaN               NaN                NaN
# 4               NaN                NaN               NaN                NaN
# ...             ...                ...               ...                ...
# 439677          NaN                NaN               NaN                NaN
# 439678          NaN                NaN               NaN                NaN
# 439679          NaN                NaN               NaN                NaN
# 439680          NaN                NaN               NaN                NaN
# 439681          NaN                NaN               NaN                NaN
#
#        player9_bet_preflop player9_bet_flop player9_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player9_bet_river player9_pocket_card1 player9_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player9_name  player10_total_bet  player10_bankroll  \
# 0               NaN                 NaN                NaN
# 1               NaN                 NaN                NaN
# 2               NaN                 NaN                NaN
# 3               NaN                 NaN                NaN
# 4               NaN                 NaN                NaN
# ...             ...                 ...                ...
# 439677          NaN                 NaN                NaN
# 439678          NaN                 NaN                NaN
# 439679          NaN                 NaN                NaN
# 439680          NaN                 NaN                NaN
# 439681          NaN                 NaN                NaN
#
#         player10_total_win player10_bet_preflop player10_bet_flop  \
# 0                      NaN                  NaN               NaN
# 1                      NaN                  NaN               NaN
# 2                      NaN                  NaN               NaN
# 3                      NaN                  NaN               NaN
# 4                      NaN                  NaN               NaN
# ...                    ...                  ...               ...
# 439677                 NaN                  NaN               NaN
# 439678                 NaN                  NaN               NaN
# 439679                 NaN                  NaN               NaN
# 439680                 NaN                  NaN               NaN
# 439681                 NaN                  NaN               NaN
#
#        player10_bet_turn player10_bet_river player10_pocket_card1  \
# 0                    NaN                NaN                   NaN
# 1                    NaN                NaN                   NaN
# 2                    NaN                NaN                   NaN
# 3                    NaN                NaN                   NaN
# 4                    NaN                NaN                   NaN
# ...                  ...                ...                   ...
# 439677               NaN                NaN                   NaN
# 439678               NaN                NaN                   NaN
# 439679               NaN                NaN                   NaN
# 439680               NaN                NaN                   NaN
# 439681               NaN                NaN                   NaN
#
#        player10_pocket_card2 player10_name  player11_total_bet  \
# 0                        NaN           NaN                 NaN
# 1                        NaN           NaN                 NaN
# 2                        NaN           NaN                 NaN
# 3                        NaN           NaN                 NaN
# 4                        NaN           NaN                 NaN
# ...                      ...           ...                 ...
# 439677                   NaN           NaN                 NaN
# 439678                   NaN           NaN                 NaN
# 439679                   NaN           NaN                 NaN
# 439680                   NaN           NaN                 NaN
# 439681                   NaN           NaN                 NaN
#
#         player11_bankroll  player11_total_win player11_bet_preflop  \
# 0                     NaN                 NaN                  NaN
# 1                     NaN                 NaN                  NaN
# 2                     NaN                 NaN                  NaN
# 3                     NaN                 NaN                  NaN
# 4                     NaN                 NaN                  NaN
# ...                   ...                 ...                  ...
# 439677                NaN                 NaN                  NaN
# 439678                NaN                 NaN                  NaN
# 439679                NaN                 NaN                  NaN
# 439680                NaN                 NaN                  NaN
# 439681                NaN                 NaN                  NaN
#
#        player11_bet_flop player11_bet_turn player11_bet_river  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 439677               NaN               NaN                NaN
# 439678               NaN               NaN                NaN
# 439679               NaN               NaN                NaN
# 439680               NaN               NaN                NaN
# 439681               NaN               NaN                NaN
#
#        player11_pocket_card1 player11_pocket_card2 player11_name  \
# 0                        NaN                   NaN           NaN
# 1                        NaN                   NaN           NaN
# 2                        NaN                   NaN           NaN
# 3                        NaN                   NaN           NaN
# 4                        NaN                   NaN           NaN
# ...                      ...                   ...           ...
# 439677                   NaN                   NaN           NaN
# 439678                   NaN                   NaN           NaN
# 439679                   NaN                   NaN           NaN
# 439680                   NaN                   NaN           NaN
# 439681                   NaN                   NaN           NaN
#
#         player12_total_bet  player12_bankroll  player12_total_win  \
# 0                      NaN                NaN                 NaN
# 1                      NaN                NaN                 NaN
# 2                      NaN                NaN                 NaN
# 3                      NaN                NaN                 NaN
# 4                      NaN                NaN                 NaN
# ...                    ...                ...                 ...
# 439677                 NaN                NaN                 NaN
# 439678                 NaN                NaN                 NaN
# 439679                 NaN                NaN                 NaN
# 439680                 NaN                NaN                 NaN
# 439681                 NaN                NaN                 NaN
#
#        player12_bet_preflop player12_bet_flop player12_bet_turn  \
# 0                       NaN               NaN               NaN
# 1                       NaN               NaN               NaN
# 2                       NaN               NaN               NaN
# 3                       NaN               NaN               NaN
# 4                       NaN               NaN               NaN
# ...                     ...               ...               ...
# 439677                  NaN               NaN               NaN
# 439678                  NaN               NaN               NaN
# 439679                  NaN               NaN               NaN
# 439680                  NaN               NaN               NaN
# 439681                  NaN               NaN               NaN
#
#        player12_bet_river player12_pocket_card1 player12_pocket_card2  \
# 0                     NaN                   NaN                   NaN
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# ...                   ...                   ...                   ...
# 439677                NaN                   NaN                   NaN
# 439678                NaN                   NaN                   NaN
# 439679                NaN                   NaN                   NaN
# 439680                NaN                   NaN                   NaN
# 439681                NaN                   NaN                   NaN
#
#        player12_name
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 439677           NaN
# 439678           NaN
# 439679           NaN
# 439680           NaN
# 439681           NaN
#
# [207279 rows x 139 columns]

# %%
def extract_cols_based_on_players_num(df:pd.DataFrame, players_num:int):
    target_df = df[df.players_num == players_num]
    columns_to_drop = [
    col for col in df.columns 
    if (
        (match := re.search(r"(player(\d+).+|board_card_(\d+))", col)) 
        and 
        any(int(num) > players_num for num in match.groups() if num and num.isdigit())
    )
    ]
    return df.drop(columns=columns_to_drop)

# %%
df_players_2 = extract_cols_based_on_players_num(df, 2)
df_players_2
# Out:
#         game_id  dealer_id  players_num  year month  timestamp board_card_1  \
# 0             3          1            2  1995    05  800160769            -
# 1             3          1            2  1995    05  800160788           Jc
# 2             3          1            2  1995    05  800160827           9h
# 3             3          1            2  1995    05  800160846           Qh
# 4             3          1            2  1995    05  800160880           As
# ...         ...        ...          ...   ...   ...        ...          ...
# 439677        3          1            2  2001    08  998722150            -
# 439678        3          1            2  2001    08  998733998           4h
# 439679        3          1            2  2001    08  998734040           4d
# 439680        3          1            2  2001    08  998734063           6h
# 439681        3          1            2  2001    08  998734076           Ac
#
#        board_card_2  player1_total_bet  player1_bankroll  player1_total_win  \
# 0                 -                 25              8371                  0
# 1                Qs                350              8060                600
# 2                7s                150              8096                250
# 3                6s                150              8210                  0
# 4                3c                250              8346                450
# ...             ...                ...               ...                ...
# 439677            -                 25              6115                 75
# 439678           Ts               2050              5846                  0
# 439679           3h                350             11390                600
# 439680           9s                 50              3546                  0
# 439681           Qh               3596             11690               7092
#
#        player1_bet_preflop player1_bet_flop player1_bet_turn  \
# 0                       Bf                -                -
# 1                      Bcc               kc               kr
# 2                       Br                b                -
# 3                      Brc               kf                -
# 4                       Br               br                -
# ...                    ...              ...              ...
# 439677                   B                -                -
# 439678                 Brc                k                k
# 439679                  Bc                k                k
# 439680                  Bc                k                k
# 439681                  Bc               br               br
#
#        player1_bet_river player1_pocket_card1 player1_pocket_card2  \
# 0                      -                    -                    -
# 1                      -                    -                    -
# 2                      -                    -                    -
# 3                      -                    -                    -
# 4                      -                    -                    -
# ...                  ...                  ...                  ...
# 439677                 -                    -                    -
# 439678        brrrrrrrrr                   3c                   8s
# 439679                br                    -                    -
# 439680                kf                    -                    -
# 439681  brrrrrrrrrrrrrrr                   Qd                   7s
#
#        player1_name  player2_total_bet  player2_bankroll  player2_total_win  \
# 0                A8                 50              8035                 75
# 1           Schween                250              8346                  0
# 2                A8                100              8310                  0
# 3           Schween                200              8196                350
# 4                A8                200              8060                  0
# ...             ...                ...               ...                ...
# 439677     fatpat55                 50              8445                  0
# 439678     fatpat55               2050              9340               4100
# 439679      rivrgod                250              3796                  0
# 439680     fatpat55                150             11640                200
# 439681      rivrgod               3496              3496                  0
#
#        player2_bet_preflop player2_bet_flop player2_bet_turn  \
# 0                        B                -                -
# 1                       Br                b               bf
# 2                       Bc                f                -
# 3                       Br                b                -
# 4                       Bc               rf                -
# ...                    ...              ...              ...
# 439677                  BQ                -                -
# 439678                  Br                k                k
# 439679                  Bk                k                k
# 439680                  Bk                k                k
# 439681                  Bk               rc               rc
#
#        player2_bet_river player2_pocket_card1 player2_pocket_card2  \
# 0                      -                    -                    -
# 1                      -                    -                    -
# 2                      -                    -                    -
# 3                      -                    -                    -
# 4                      -                    -                    -
# ...                  ...                  ...                  ...
# 439677                 -                    -                    -
# 439678        rrrrrrrrrc                   Qh                   8c
# 439679                rf                    -                    -
# 439680                 b                    -                    -
# 439681  rrrrrrrrrrrrrrrA                   8c                   7d
#
#        player2_name  pot_players_num_flop  pot_size_flop  \
# 0           Schween                     0              0
# 1                A8                     2            200
# 2           Schween                     2            200
# 3                A8                     2            300
# 4           Schween                     2            200
# ...             ...                   ...            ...
# 439677       zeigen                     0              0
# 439678      rivrgod                     2            300
# 439679     fatpat55                     2            100
# 439680      rivrgod                     2            100
# 439681     fatpat55                     2            100
#
#         pot_players_num_turn  pot_size_turn  pot_players_num_river  \
# 0                          0              0                      0
# 1                          2            300                      0
# 2                          0              0                      0
# 3                          0              0                      0
# 4                          0              0                      0
# ...                      ...            ...                    ...
# 439677                     0              0                      0
# 439678                     2            300                      2
# 439679                     2            100                      2
# 439680                     2            100                      2
# 439681                     2            400                      2
#
#         pot_size_river  pot_players_num_showdown  pot_size_showdown
# 0                    0                         1                 75
# 1                    0                         1                600
# 2                    0                         1                250
# 3                    0                         1                350
# 4                    0                         1                450
# ...                ...                       ...                ...
# 439677               0                         1                 75
# 439678             300                         2               4100
# 439679             100                         1                600
# 439680             100                         1                200
# 439681            1000                         2               7092
#
# [439682 rows x 36 columns]

# %%
df_players_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439682 entries, 0 to 439681
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   game_id                   439682 non-null  int64
#  1   dealer_id                 439682 non-null  int64
#  2   players_num               439682 non-null  int64
#  3   year                      439682 non-null  object
#  4   month                     439682 non-null  object
#  5   timestamp                 439682 non-null  object
#  6   board_card_1              439682 non-null  object
#  7   board_card_2              439682 non-null  object
#  8   player1_total_bet         439682 non-null  int64
#  9   player1_bankroll          439682 non-null  int64
#  10  player1_total_win         439682 non-null  int64
#  11  player1_bet_preflop       439682 non-null  object
#  12  player1_bet_flop          439682 non-null  object
#  13  player1_bet_turn          439682 non-null  object
#  14  player1_bet_river         439682 non-null  object
#  15  player1_pocket_card1      439682 non-null  object
#  16  player1_pocket_card2      439682 non-null  object
#  17  player1_name              439682 non-null  object
#  18  player2_total_bet         439682 non-null  int64
#  19  player2_bankroll          439682 non-null  int64
#  20  player2_total_win         439682 non-null  int64
#  21  player2_bet_preflop       439682 non-null  object
#  22  player2_bet_flop          439682 non-null  object
#  23  player2_bet_turn          439682 non-null  object
#  24  player2_bet_river         439682 non-null  object
#  25  player2_pocket_card1      439682 non-null  object
#  26  player2_pocket_card2      439682 non-null  object
#  27  player2_name              439682 non-null  object
#  28  pot_players_num_flop      439682 non-null  int64
#  29  pot_size_flop             439682 non-null  int64
#  30  pot_players_num_turn      439682 non-null  int64
#  31  pot_size_turn             439682 non-null  int64
#  32  pot_players_num_river     439682 non-null  int64
#  33  pot_size_river            439682 non-null  int64
#  34  pot_players_num_showdown  439682 non-null  int64
#  35  pot_size_showdown         439682 non-null  int64
# dtypes: int64(17), object(19)
# memory usage: 120.8+ MB

# %%
df_players_3 = extract_cols_based_on_players_num(df, 3)
df_players_3
# Out:
#         game_id  dealer_id  players_num  year month  timestamp board_card_1  \
# 0             3          1            2  1995    05  800160769            -
# 1             3          1            2  1995    05  800160788           Jc
# 2             3          1            2  1995    05  800160827           9h
# 3             3          1            2  1995    05  800160846           Qh
# 4             3          1            2  1995    05  800160880           As
# ...         ...        ...          ...   ...   ...        ...          ...
# 439677        3          1            2  2001    08  998722150            -
# 439678        3          1            2  2001    08  998733998           4h
# 439679        3          1            2  2001    08  998734040           4d
# 439680        3          1            2  2001    08  998734063           6h
# 439681        3          1            2  2001    08  998734076           Ac
#
#        board_card_2 board_card_3  player1_total_bet  player1_bankroll  \
# 0                 -            -                 25              8371
# 1                Qs           6s                350              8060
# 2                7s           Qc                150              8096
# 3                6s           3s                150              8210
# 4                3c           6s                250              8346
# ...             ...          ...                ...               ...
# 439677            -            -                 25              6115
# 439678           Ts           2h               2050              5846
# 439679           3h           5d                350             11390
# 439680           9s           4d                 50              3546
# 439681           Qh           9d               3596             11690
#
#         player1_total_win player1_bet_preflop player1_bet_flop  \
# 0                       0                  Bf                -
# 1                     600                 Bcc               kc
# 2                     250                  Br                b
# 3                       0                 Brc               kf
# 4                     450                  Br               br
# ...                   ...                 ...              ...
# 439677                 75                   B                -
# 439678                  0                 Brc                k
# 439679                600                  Bc                k
# 439680                  0                  Bc                k
# 439681               7092                  Bc               br
#
#        player1_bet_turn player1_bet_river player1_pocket_card1  \
# 0                     -                 -                    -
# 1                    kr                 -                    -
# 2                     -                 -                    -
# 3                     -                 -                    -
# 4                     -                 -                    -
# ...                 ...               ...                  ...
# 439677                -                 -                    -
# 439678                k        brrrrrrrrr                   3c
# 439679                k                br                    -
# 439680                k                kf                    -
# 439681               br  brrrrrrrrrrrrrrr                   Qd
#
#        player1_pocket_card2 player1_name  player2_total_bet  player2_bankroll  \
# 0                         -           A8                 50              8035
# 1                         -      Schween                250              8346
# 2                         -           A8                100              8310
# 3                         -      Schween                200              8196
# 4                         -           A8                200              8060
# ...                     ...          ...                ...               ...
# 439677                    -     fatpat55                 50              8445
# 439678                   8s     fatpat55               2050              9340
# 439679                    -      rivrgod                250              3796
# 439680                    -     fatpat55                150             11640
# 439681                   7s      rivrgod               3496              3496
#
#         player2_total_win player2_bet_preflop player2_bet_flop  \
# 0                      75                   B                -
# 1                       0                  Br                b
# 2                       0                  Bc                f
# 3                     350                  Br                b
# 4                       0                  Bc               rf
# ...                   ...                 ...              ...
# 439677                  0                  BQ                -
# 439678               4100                  Br                k
# 439679                  0                  Bk                k
# 439680                200                  Bk                k
# 439681                  0                  Bk               rc
#
#        player2_bet_turn player2_bet_river player2_pocket_card1  \
# 0                     -                 -                    -
# 1                    bf                 -                    -
# 2                     -                 -                    -
# 3                     -                 -                    -
# 4                     -                 -                    -
# ...                 ...               ...                  ...
# 439677                -                 -                    -
# 439678                k        rrrrrrrrrc                   Qh
# 439679                k                rf                    -
# 439680                k                 b                    -
# 439681               rc  rrrrrrrrrrrrrrrA                   8c
#
#        player2_pocket_card2 player2_name  pot_players_num_flop  pot_size_flop  \
# 0                         -      Schween                     0              0
# 1                         -           A8                     2            200
# 2                         -      Schween                     2            200
# 3                         -           A8                     2            300
# 4                         -      Schween                     2            200
# ...                     ...          ...                   ...            ...
# 439677                    -       zeigen                     0              0
# 439678                   8c      rivrgod                     2            300
# 439679                    -     fatpat55                     2            100
# 439680                    -      rivrgod                     2            100
# 439681                   7d     fatpat55                     2            100
#
#         pot_players_num_turn  pot_size_turn  pot_players_num_river  \
# 0                          0              0                      0
# 1                          2            300                      0
# 2                          0              0                      0
# 3                          0              0                      0
# 4                          0              0                      0
# ...                      ...            ...                    ...
# 439677                     0              0                      0
# 439678                     2            300                      2
# 439679                     2            100                      2
# 439680                     2            100                      2
# 439681                     2            400                      2
#
#         pot_size_river  pot_players_num_showdown  pot_size_showdown  \
# 0                    0                         1                 75
# 1                    0                         1                600
# 2                    0                         1                250
# 3                    0                         1                350
# 4                    0                         1                450
# ...                ...                       ...                ...
# 439677               0                         1                 75
# 439678             300                         2               4100
# 439679             100                         1                600
# 439680             100                         1                200
# 439681            1000                         2               7092
#
#         player3_total_bet  player3_bankroll  player3_total_win  \
# 0                     NaN               NaN                NaN
# 1                     NaN               NaN                NaN
# 2                     NaN               NaN                NaN
# 3                     NaN               NaN                NaN
# 4                     NaN               NaN                NaN
# ...                   ...               ...                ...
# 439677                NaN               NaN                NaN
# 439678                NaN               NaN                NaN
# 439679                NaN               NaN                NaN
# 439680                NaN               NaN                NaN
# 439681                NaN               NaN                NaN
#
#        player3_bet_preflop player3_bet_flop player3_bet_turn  \
# 0                      NaN              NaN              NaN
# 1                      NaN              NaN              NaN
# 2                      NaN              NaN              NaN
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# ...                    ...              ...              ...
# 439677                 NaN              NaN              NaN
# 439678                 NaN              NaN              NaN
# 439679                 NaN              NaN              NaN
# 439680                 NaN              NaN              NaN
# 439681                 NaN              NaN              NaN
#
#        player3_bet_river player3_pocket_card1 player3_pocket_card2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 439677               NaN                  NaN                  NaN
# 439678               NaN                  NaN                  NaN
# 439679               NaN                  NaN                  NaN
# 439680               NaN                  NaN                  NaN
# 439681               NaN                  NaN                  NaN
#
#        player3_name
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 439677          NaN
# 439678          NaN
# 439679          NaN
# 439680          NaN
# 439681          NaN
#
# [439682 rows x 47 columns]
